# %%
import os
import io
import logging
import numpy as np
import cv2
from PIL import Image
from scipy.ndimage import gaussian_filter
from pathlib import Path

# ── الإعدادات القياسية للمشروع ──────────────────────────────────────────────
TARGET_SIZE = (256, 256)          # الحجم المعتمد[cite: 2]
ELA_QUALITY = 90                  # جودة ELA المطلوبة[cite: 2]
CANNY_LOW   = 100                 # حد كاني الأدنى[cite: 2]
CANNY_HIGH  = 200                 # حد كاني الأعلى[cite: 2]
GAUSS_SIGMA = 1.0                 
EPSILON     = 1e-8                

SUPPORTED_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

logging.basicConfig(level=logging.INFO, format="%(levelname)s | %(message)s")
log = logging.getLogger(__name__)

# ── الدوال التقنية (Forensic Logic)[cite: 2] ────────────────────────────────

def _load_rgb(image_path):
    img = Image.open(image_path).convert("RGB")
    img = img.resize((TARGET_SIZE[1], TARGET_SIZE[0]), Image.LANCZOS)
    return np.array(img, dtype=np.uint8)

def _normalize(arr):
    a_min, a_max = arr.min(), arr.max()
    if a_max - a_min < EPSILON:
        return np.zeros_like(arr, dtype=np.float32)
    return ((arr - a_min) / (a_max - a_min)).astype(np.float32)

def compute_ela(image_path):
    """استخراج Error Level Analysis[cite: 2]"""
    original = _load_rgb(image_path).astype(np.float32)
    buf = io.BytesIO()
    Image.fromarray(original.astype(np.uint8)).save(buf, format="JPEG", quality=ELA_QUALITY)
    buf.seek(0)
    recompressed = np.array(Image.open(buf).convert("RGB"), dtype=np.float32)
    ela_map = np.abs(original - recompressed)
    ela_map = np.sqrt(np.sum(ela_map ** 2, axis=2, keepdims=True))
    return _normalize(ela_map).astype(np.float32)

def compute_noise_residual(image):
    """استخراج Noise Residual[cite: 2]"""
    img = image.astype(np.float32) / 255.0
    denoised = np.stack([gaussian_filter(img[:, :, c], sigma=GAUSS_SIGMA) for c in range(3)], axis=2)
    residual = np.abs(img - denoised)
    weights = np.array([0.2126, 0.7152, 0.0722], dtype=np.float32)
    lum_residual = np.sum(residual * weights, axis=2, keepdims=True)
    return _normalize(lum_residual).astype(np.float32)

def compute_edge_map(image):
    """استخراج Edge Map باستخدام Canny[cite: 2]"""
    img_uint8 = image if image.max() > 1.0 else (image * 255).astype(np.uint8)
    gray = cv2.cvtColor(img_uint8, cv2.COLOR_RGB2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    edges = cv2.Canny(blurred, CANNY_LOW, CANNY_HIGH)
    edge_map = edges[:, :, np.newaxis].astype(np.float32) / 255.0
    return _normalize(edge_map).astype(np.float32)

# ── تشغيل المعالجة في كاجل ────────────────────────────────────────────────

def run_processing_on_kaggle(input_dir, output_dir):
    image_dir = Path(input_dir)
    out_path = Path(output_dir)
    out_path.mkdir(parents=True, exist_ok=True)

    # البحث عن الصور في مجلد الإدخال (Read-only)
    image_paths = sorted([
        p for p in image_dir.rglob("*") 
        if p.suffix.lower() in SUPPORTED_EXTS and "_gt" not in p.name
    ])

    log.info(f"جاري معالجة {len(image_paths)} صورة من مجلد الإدخال...")

    for idx, img_path in enumerate(image_paths):
        stem = img_path.stem
        try:
            rgb = _load_rgb(str(img_path))
            
            # استخراج الميزات الثلاث[cite: 2]
            ela = compute_ela(str(img_path))
            noise = compute_noise_residual(rgb)
            edge = compute_edge_map(rgb)

            # الحفظ في مجلد العمل (Working Directory) ليتم تحويله لاحقاً لـ Dataset
            np.save(out_path / f"{stem}_ela.npy", ela)
            np.save(out_path / f"{stem}_noise.npy", noise)
            np.save(out_path / f"{stem}_edge.npy", edge)

            if (idx + 1) % 100 == 0:
                log.info(f"  [{idx+1}/{len(image_paths)}] تم الانتهاء من {stem}")

        except Exception as e:
            log.error(f"  فشل في {stem}: {e}")

    log.info(f" انتهت المهمة! جميع الملفات محفوظة في: {output_dir}")

# --- تحديد المسارات في كاجل ---
# ملاحظة: تأكد من اسم المجلد الخاص بك في الـ input
KAGGLE_INPUT = "/kaggle/input/datasets/divg07/casia-20-image-tampering-detection-dataset/CASIA2"
KAGGLE_OUTPUT = "/kaggle/working/processed_features"

run_processing_on_kaggle(KAGGLE_INPUT, KAGGLE_OUTPUT)
# Out:
# INFO | جاري معالجة 12614 صورة من مجلد الإدخال...
# INFO |   [100/12614] تم الانتهاء من Au_ani_00100
# INFO |   [200/12614] تم الانتهاء من Au_ani_10196
# INFO |   [300/12614] تم الانتهاء من Au_ani_30002
# INFO |   [400/12614] تم الانتهاء من Au_ani_30102
# INFO |   [500/12614] تم الانتهاء من Au_ani_30202
# INFO |   [600/12614] تم الانتهاء من Au_ani_30302
# INFO |   [700/12614] تم الانتهاء من Au_ani_30402
# INFO |   [800/12614] تم الانتهاء من Au_ani_30502
# INFO |   [900/12614] تم الانتهاء من Au_ani_30602
# INFO |   [1000/12614] تم الانتهاء من Au_ani_30702
# INFO |   [1100/12614] تم الانتهاء من Au_arc_00006
# INFO |   [1200/12614] تم الانتهاء من Au_arc_10105
# INFO |   [1300/12614] تم الانتهاء من Au_arc_20075
# INFO |   [1400/12614] تم الانتهاء من Au_arc_30074
# INFO |   [1500/12614] تم الانتهاء من Au_arc_30174
# INFO |   [1600/12614] تم الانتهاء من Au_arc_30274
# INFO |   [1700/12614] تم الانتهاء من Au_arc_30374
# INFO |   [1800/12614] تم الانتهاء من Au_arc_30474
# INFO |   [1900/12614] تم الانتهاء من Au_arc_30574
# INFO |   [2000/12614] تم الانتهاء من Au_arc_30674
# INFO |   [2100/12614] تم الانتهاء من Au_arc_30774
# INFO |   [2200/12614] تم الانتهاء من Au_art_00031
# INFO |   [2300/12614] تم الانتهاء من Au_art_10113
# INFO |   [2400/12614] تم الانتهاء من Au_art_30003
# INFO |   [2500/12614] تم الانتهاء من Au_art_30103
# INFO |   [2600/12614] تم الانتهاء من Au_art_30203
# INFO |   [2700/12614] تم الانتهاء من Au_art_30303
# INFO |   [2800/12614] تم الانتهاء من Au_art_30403
# INFO |   [2900/12614] تم الانتهاء من Au_art_30503
# INFO |   [3000/12614] تم الانتهاء من Au_art_30603
# INFO |   [3100/12614] تم الانتهاء من Au_cha_00018
# INFO |   [3200/12614] تم الانتهاء من Au_cha_10116
# INFO |   [3300/12614] تم الانتهاء من Au_cha_20005
# INFO |   [3400/12614] تم الانتهاء من Au_cha_30057
# INFO |   [3500/12614] تم الانتهاء من Au_cha_30157
# INFO |   [3600/12614] تم الانتهاء من Au_cha_30257
# INFO |   [3700/12614] تم الانتهاء من Au_cha_30357
# INFO |   [3800/12614] تم الانتهاء من Au_cha_30457
# INFO |   [3900/12614] تم الانتهاء من Au_cha_30557
# INFO |   [4000/12614] تم الانتهاء من Au_cha_30657
# INFO |   [4100/12614] تم الانتهاء من Au_ind_00038
# INFO |   [4200/12614] تم الانتهاء من Au_ind_20032
# INFO |   [4300/12614] تم الانتهاء من Au_ind_30067
# INFO |   [4400/12614] تم الانتهاء من Au_ind_30167
# INFO |   [4500/12614] تم الانتهاء من Au_nat_00092
# INFO |   [4600/12614] تم الانتهاء من Au_nat_20020
# INFO |   [4700/12614] تم الانتهاء من Au_nat_30020
# INFO |   [4800/12614] تم الانتهاء من Au_nat_30120
# INFO |   [4900/12614] تم الانتهاء من Au_nat_30220
# INFO |   [5000/12614] تم الانتهاء من Au_nat_30320
# INFO |   [5100/12614] تم الانتهاء من Au_nat_30420
# INFO |   [5200/12614] تم الانتهاء من Au_nat_30520
# INFO |   [5300/12614] تم الانتهاء من Au_nat_30620
# INFO |   [5400/12614] تم الانتهاء من Au_nat_30720
# INFO |   [5500/12614] تم الانتهاء من Au_pla_00084
# INFO |   [5600/12614] تم الانتهاء من Au_pla_20053
# INFO |   [5700/12614] تم الانتهاء من Au_pla_30053
# INFO |   [5800/12614] تم الانتهاء من Au_pla_30153
# INFO |   [5900/12614] تم الانتهاء من Au_pla_30253
# INFO |   [6000/12614] تم الانتهاء من Au_pla_30353
# INFO |   [6100/12614] تم الانتهاء من Au_pla_30453
# INFO |   [6200/12614] تم الانتهاء من Au_pla_30553
# INFO |   [6300/12614] تم الانتهاء من Au_pla_30653
# INFO |   [6400/12614] تم الانتهاء من Au_sec_00008
# INFO |   [6500/12614] تم الانتهاء من Au_sec_10105
# INFO |   [6600/12614] تم الانتهاء من Au_sec_20089
# INFO |   [6700/12614] تم الانتهاء من Au_sec_30089
# INFO |   [6800/12614] تم الانتهاء من Au_sec_30189
# INFO |   [6900/12614] تم الانتهاء من Au_sec_30289
# INFO |   [7000/12614] تم الانتهاء من Au_sec_30389
# INFO |   [7100/12614] تم الانتهاء من Au_sec_30489
# INFO |   [7200/12614] تم الانتهاء من Au_sec_30589
# INFO |   [7300/12614] تم الانتهاء من Au_sec_30689
# INFO |   [7400/12614] تم الانتهاء من Au_txt_00055
# INFO |   [7500/12614] تم الانتهاء من Tp_D_CNN_M_B_nat10139_nat00097_11948
# INFO |   [7600/12614] تم الانتهاء من Tp_D_CRN_M_N_ani10102_ani00097_10091
# INFO |   [7700/12614] تم الانتهاء من Tp_D_CRN_M_O_arc00027_ani00030_10005
# INFO |   [7800/12614] تم الانتهاء من Tp_D_CRN_S_N_nat10164_ani00005_12093
# INFO |   [7900/12614] تم الانتهاء من Tp_D_NNN_M_B_nat10128_ani00058_11541
# INFO |   [8000/12614] تم الانتهاء من Tp_D_NNN_M_N_sec00058_nat00097_11273
# INFO |   [8100/12614] تم الانتهاء من Tp_D_NNN_S_N_ani20005_ani20001_02048
# INFO |   [8200/12614] تم الانتهاء من Tp_D_NNN_S_N_pla00063_pla00064_11223
# INFO |   [8300/12614] تم الانتهاء من Tp_D_NRD_S_N_art10014_art10011_20095
# INFO |   [8400/12614] تم الانتهاء من Tp_D_NRN_M_N_ani00083_ani00083_10040
# INFO |   [8500/12614] تم الانتهاء من Tp_D_NRN_M_N_cha10141_cha10142_12236
# INFO |   [8600/12614] تم الانتهاء من Tp_D_NRN_M_N_nat10136_arc00069_11918
# INFO |   [8700/12614] تم الانتهاء من Tp_D_NRN_M_N_sec10112_art00098_10343
# INFO |   [8800/12614] تم الانتهاء من Tp_D_NRN_S_B_ind10001_ind10002_20009
# INFO |   [8900/12614] تم الانتهاء من Tp_D_NRN_S_N_ani10190_ani10196_12429
# INFO |   [9000/12614] تم الانتهاء من Tp_D_NRN_S_N_art00099_ani00005_00539
# INFO |   [9100/12614] تم الانتهاء من Tp_D_NRN_S_N_cha10197_cha00062_12367
# INFO |   [9200/12614] تم الانتهاء من Tp_D_NRN_S_N_nat10145_ani00097_11980
# INFO |   [9300/12614] تم الانتهاء من Tp_D_NRN_S_N_sec00071_sec00071_00092
# INFO |   [9400/12614] تم الانتهاء من Tp_S_CNN_M_N_arc00064_arc00064_10432
# INFO |   [9500/12614] تم الانتهاء من Tp_S_CNN_M_N_nat10151_nat10151_12110
# INFO |   [9600/12614] تم الانتهاء من Tp_S_CNN_S_B_sec00008_sec00008_00770
# INFO |   [9700/12614] تم الانتهاء من Tp_S_CNN_S_N_art20090_art20090_02307
# INFO |   [9800/12614] تم الانتهاء من Tp_S_CNN_S_N_pla00032_pla00032_10993
# INFO |   [9900/12614] تم الانتهاء من Tp_S_CRD_S_B_art00005_art00005_01430
# INFO |   [10000/12614] تم الانتهاء من Tp_S_CRN_M_N_pla00088_pla00088_10852
# INFO |   [10100/12614] تم الانتهاء من Tp_S_CRN_S_N_cha10160_cha10160_12259
# INFO |   [10200/12614] تم الانتهاء من Tp_S_CRN_S_N_sec00097_sec00097_10128
# INFO |   [10300/12614] تم الانتهاء من Tp_S_NND_S_N_art00092_art00092_00006
# INFO |   [10400/12614] تم الانتهاء من Tp_S_NNN_M_N_ani00074_ani00074_10445
# INFO |   [10500/12614] تم الانتهاء من Tp_S_NNN_S_B_arc00019_arc00019_20028
# INFO |   [10600/12614] تم الانتهاء من Tp_S_NNN_S_B_cha20037_cha20037_02430
# INFO |   [10700/12614] تم الانتهاء من Tp_S_NNN_S_B_pla20016_pla20016_01916
# INFO |   [10800/12614] تم الانتهاء من Tp_S_NNN_S_N_ani00100_ani00100_11649
# INFO |   [10900/12614] تم الانتهاء من Tp_S_NNN_S_N_arc00085_arc00085_01045
# INFO |   [11000/12614] تم الانتهاء من Tp_S_NNN_S_N_art00001_art00001_00918
# INFO |   [11100/12614] تم الانتهاء من Tp_S_NNN_S_N_art20042_art20042_01848
# INFO |   [11200/12614] تم الانتهاء من Tp_S_NNN_S_N_cha10165_cha10165_12244
# INFO |   [11300/12614] تم الانتهاء من Tp_S_NNN_S_N_ind00063_ind00063_10703
# INFO |   [11400/12614] تم الانتهاء من Tp_S_NNN_S_N_nat00048_nat00048_00967
# INFO |   [11500/12614] تم الانتهاء من Tp_S_NNN_S_N_nat20070_nat20070_01574
# INFO |   [11600/12614] تم الانتهاء من Tp_S_NNN_S_N_pla00084_pla00084_10454
# INFO |   [11700/12614] تم الانتهاء من Tp_S_NNN_S_N_sec00026_sec00026_10769
# INFO |   [11800/12614] تم الانتهاء من Tp_S_NNN_S_N_sec20061_sec20061_01651
# INFO |   [11900/12614] تم الانتهاء من Tp_S_NRD_S_B_sec20070_sec20070_01660
# INFO |   [12000/12614] تم الانتهاء من Tp_S_NRN_M_N_art00025_art00025_10550
# INFO |   [12100/12614] تم الانتهاء من Tp_S_NRN_S_B_nat00098_nat00098_00995
# INFO |   [12200/12614] تم الانتهاء من Tp_S_NRN_S_N_arc00091_arc00091_01039
# INFO |   [12300/12614] تم الانتهاء من Tp_S_NRN_S_N_cha00037_cha00037_11014
# INFO |   [12400/12614] تم الانتهاء من Tp_S_NRN_S_N_ind00081_ind00081_10669
# INFO |   [12500/12614] تم الانتهاء من Tp_S_NRN_S_N_pla00053_pla00053_00587
# INFO |   [12600/12614] تم الانتهاء من Tp_S_NRN_S_N_txt00071_txt00071_11300
# INFO | ✅ انتهت المهمة! جميع الملفات محفوظة في: /kaggle/working/processed_features
